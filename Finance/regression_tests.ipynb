# %%
# !pip install yfinance
# Out:
# /home/ecotrace/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 1.16.0-unknown is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ecotrace/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ecotrace/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ecotrace/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 1.16.0-unknown is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ecotrace/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ecotrace/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# Collecting yfinance
#   Downloading yfinance-0.2.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.3.0 in /home/ecotrace/.local/lib/python3.8/site-packages (from yfinance) (1.4.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/ecotrace/.local/lib/python3.8/site-packages (from yfinance) (1.23.1)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.9 MB/s  eta 0:00:01
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /home/ecotrace/.local/lib/python3.8/site-packages (from yfinance) (4.9.2)
# Collecting appdirs>=1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pytz>=2022.5
#   Downloading pytz-2022.7-py2.py3-none-any.whl (499 kB)
#      |████████████████████████████████| 499 kB 32.7 MB/s eta 0:00:01
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (110 kB)
#      |████████████████████████████████| 110 kB 27.6 MB/s eta 0:00:01
# Collecting cryptography>=3.3.2
#   Downloading cryptography-38.0.4-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 24.7 MB/s eta 0:00:01
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 32.2 MB/s eta 0:00:01
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 49.3 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ecotrace/.local/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ecotrace/.local/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.26->yfinance) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.26->yfinance) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.26->yfinance) (2019.11.28)
# Requirement already satisfied: cffi>=1.12 in /home/ecotrace/.local/lib/python3.8/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: six>=1.9 in /usr/lib/python3/dist-packages (from html5lib>=1.1->yfinance) (1.14.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /home/ecotrace/.local/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: requests, multitasking, appdirs, pytz, frozendict, cryptography, soupsieve, beautifulsoup4, webencodings, html5lib, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
#   WARNING: The script sample is installed in '/home/ecotrace/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.11.1 cryptography-38.0.4 frozendict-2.3.4 html5lib-1.1 multitasking-0.0.11 pytz-2022.7 requests-2.28.1 soupsieve-2.3.2.post1 webencodings-0.5.1 yfinance-0.2.3

# %%
import numpy as np
import pandas as pd
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import datetime as dt
import mplfinance as mpf

# %%
def save_to_csv_from_yahoo(ticker, syear, smonth, sday, eyear, emonth, eday):
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    
    #df = web.DataReader(ticker, 'yahoo', start, end)
    df = pdr.get_data_yahoo(ticker, start, end)
    
    df.to_csv("/home/ecotrace/Desktop/" + ticker + ".csv")
    return df

# %%
sigla = 'AMZN' #'AMZN' #'BTC-USD'
save_to_csv_from_yahoo(sigla, 2022, 12, 1, 2022, 12, 28)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2022-12-01  96.989998  97.230003  94.919998  95.500000  95.500000   68488000
# 2022-12-02  94.480003  95.360001  93.779999  94.129997  94.129997   72427000
# 2022-12-05  93.050003  94.059998  90.820000  91.010002  91.010002   71535500
# 2022-12-06  90.500000  91.040001  87.900002  88.250000  88.250000   75503600
# 2022-12-07  88.339996  89.889999  87.480003  88.459999  88.459999   68086900
# 2022-12-08  89.239998  90.860001  87.879997  90.349998  90.349998   73305900
# 2022-12-09  88.900002  90.300003  88.629997  89.089996  89.089996   67316900
# 2022-12-12  89.209999  90.580002  87.870003  90.550003  90.550003   61999800
# 2022-12-13  95.230003  96.250000  90.519997  92.489998  92.489998  100212000
# 2022-12-14  92.500000  93.459999  89.870003  91.580002  91.580002   70298000
# 2022-12-15  89.889999  89.970001  87.470001  88.449997  88.449997   84802900
# 2022-12-16  88.269997  89.349998  86.730003  87.860001  87.860001  146044000
# 2022-12-19  87.510002  87.629997  84.510002  84.919998  84.919998   83531500
# 2022-12-20  85.330002  86.610001  84.330002  85.190002  85.190002   74348300
# 2022-12-21  86.180000  87.230003  85.209999  86.769997  86.769997   59267200
# 2022-12-22  85.519997  85.680000  82.250000  83.790001  83.790001   81431300
# 2022-12-23  83.250000  85.779999  82.930000  85.250000  85.250000   57390800
# 2022-12-27  84.970001  85.349998  83.000000  83.040001  83.040001   57284000
